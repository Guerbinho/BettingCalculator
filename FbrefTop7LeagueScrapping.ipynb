# %%
import requests
standing_url = "https://fbref.com/en/comps/20/Bundesliga-Stats"
data = requests.get(standing_url)
data.text
from bs4 import BeautifulSoup
soup = BeautifulSoup(data.text)
standing_table = soup.select("table.stats_table")[0]
standing_table
links  = standing_table.find_all("a")
links

links = [l.get("href") for l in links]
links
links = [l for l in links if '/squads/' in l]
links
team_urls = [f"https://fbref.com{l}" for l in links]
team_urls
team_url = team_urls[5]
data = requests.get(team_url)
data.text

import pandas as pd
matches = pd.read_html(data.text, match = "Scores & Fixtures")
matches

matches[0].head()
soup = BeautifulSoup(data.text)
links = soup.find_all("a")
links = [l.get("href") for l in links]
links = [l for l in links if l and "all_comps/keeper/" in l]
links
data = requests.get(f"https://fbref.com{links[0]}")
data.text

links2 = soup.find_all("a")
links2 = [l2.get("href") for l2 in links2]
links2 = [l2 for l2 in links2 if l2 and "all_comps/passing_types/" in l2]
data2 = requests.get(f"https://fbref.com{links2[0]}")
data2.text

links3 = soup.find_all("a")
links3 = [l3.get("href") for l3 in links3]
links3 = [l3 for l3 in links3 if l3 and "all_comps/misc/" in l3]
data3 = requests.get(f"https://fbref.com{links3[0]}")
data3.text

teamGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[0]
oppGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[1]
teamGoalKicks.head()
oppGoalKicks.head()

teampassing = pd.read_html(data2.text, match = "Pass Types")[0]
opppassing = pd.read_html(data2.text, match = "Pass Types")[1]
teampassing.head()
opppassing.head()

teammisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[0]
oppmisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[1]
teammisc.head()
oppmisc.head()

oppGoalKicks.columns = oppGoalKicks.columns.droplevel()
oppGoalKicks.head()
teamGoalKicks.columns = teamGoalKicks.columns.droplevel()
teamGoalKicks.head()


opppassing.columns = opppassing.columns.droplevel()
opppassing.head()
teampassing.columns = teampassing.columns.droplevel()
teampassing.head()

oppmisc.columns = oppmisc.columns.droplevel()
oppmisc.head()
teammisc.columns = teammisc.columns.droplevel()
teammisc.head()

team_data = matches[0].merge(teamGoalKicks[["Date", "Att"]], on = "Date").merge(oppGoalKicks[["Date", "Att"]], on = "Date").merge(teampassing[["Date", "Crs", "TI", "CK", "Off"]], on = "Date").merge(opppassing[["Date","Crs", "TI", "CK", "Off"]], on = "Date").merge(teammisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date").merge(oppmisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date")
team_data.head()

years = list(range(2023,2022,-1))
years


all_matches = []
standing_url = "https://fbref.com/en/comps/20/Bundesliga-Stats"

for year in years:
    data = requests.get(standing_url)
    soup = BeautifulSoup(data.text)
    standing_table = soup.select("table.stats_table")[0]
    
    links = standing_table.find_all("a")
    links = [l.get("href") for l in links]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
team_urls

team_urls[5].split("/")[-1].replace("-Stats", "")
team_urls[5].split("/")[-1].replace("-Stats", "").replace("-"," ")

import time
for year in years:
    data = requests.get(standing_url)
    soup = BeautifulSoup(data.text)
    standing_table = soup.select("table.stats_table")[0]
    
    links = standing_table.find_all("a")
    links = [l.get("href") for l in links]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-"," ")
        
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match= "Scores & Fixtures")[0]
        
        soup = BeautifulSoup(data.text)
        links = soup.find_all("a")
        links = [l.get("href") for l in links]
        links = [l for l in links if l and 'all_comps/keeper' in l]
        
        
        links2 = soup.find_all("a")
        links2 = [l2.get("href") for l2 in links2]
        links2 = [l2 for l2 in links2 if l2 and 'all_comps/passing_types' in l2]
        
        links3 = soup.find_all("a")
        links3 = [l3.get("href") for l3 in links3]
        links3 = [l3 for l3 in links3 if l3 and 'all_comps/misc' in l3]
        
        data = requests.get(f"https://fbref.com{links[0]}")
        teamGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[0]
        teamGoalKicks.columns = teamGoalKicks.columns.droplevel()
        oppGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[1]
        oppGoalKicks.columns = oppGoalKicks.columns.droplevel()
              
        data2 = requests.get(f"https://fbref.com{links2[0]}")
        teampassing = pd.read_html(data2.text, match = "Pass Types")[0]
        teampassing.columns = teampassing.columns.droplevel()
        opppassing = pd.read_html(data2.text, match = "Pass Types")[1]
        opppassing.columns = opppassing.columns.droplevel()
                       
        data3 = requests.get(f"https://fbref.com{links3[0]}")
        teammisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[0]
        teammisc.columns = teammisc.columns.droplevel()
        oppmisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[1]
        oppmisc.columns = oppmisc.columns.droplevel()
                         
        try:
            team_data = matches.merge(teampassing[["Date", "Crs", "TI", "CK", "Off"]], on = "Date").merge(opppassing[["Date", "Crs", "TI", "CK", "Off"]], on = "Date").merge(teamGoalKicks[["Date", "Att"]], on = "Date").merge(oppGoalKicks[["Date", "Att"]], on = "Date").merge(teammisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date").merge(oppmisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date")
       
        except ValueError:
            continue
            
        team_data = team_data[team_data["Comp"] == "Bundesliga"]
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(10)
        
match_df = pd.concat(all_matches)

match_df.columns = [c.lower() for c in match_df.columns]

match_df.to_csv("Ger1.csv")
match_df
# Out:
#           date   time        comp         round  day venue result   gf   ga  \
# 1   2022-08-05  20:30  Bundesliga   Matchweek 1  Fri  Away      W  6.0  1.0
# 2   2022-08-14  17:30  Bundesliga   Matchweek 2  Sun  Home      W  2.0  0.0
# 3   2022-08-21  17:30  Bundesliga   Matchweek 3  Sun  Away      W  7.0  0.0
# 4   2022-08-27  18:30  Bundesliga   Matchweek 4  Sat  Home      D  1.0  1.0
# 6   2022-09-03  15:30  Bundesliga   Matchweek 5  Sat  Away      D  1.0  1.0
# ..         ...    ...         ...           ...  ...   ...    ...  ...  ...
# 22  2023-02-11  15:30  Bundesliga  Matchweek 20  Sat  Home      L  1.0  3.0
# 23  2023-02-17  20:30  Bundesliga  Matchweek 21  Fri  Away      L  0.0  1.0
# 24  2023-02-25  15:30  Bundesliga  Matchweek 22  Sat  Home      L  0.0  1.0
# 25  2023-03-04  15:30  Bundesliga  Matchweek 23  Sat  Away      L  0.0  1.0
# 26  2023-03-12  15:30  Bundesliga  Matchweek 24  Sun  Away      L  1.0  2.0
#
#           opponent  ...  tklw_x  pkwon_x  crdy_y  crdr_y 2crdy_y int_y tklw_y  \
# 1   Eint Frankfurt  ...    10.0      0.0       2       0       0  17.0    9.0
# 2        Wolfsburg  ...    15.0      0.0       1       0       0  13.0    7.0
# 3           Bochum  ...    14.0      1.0       1       0       0  11.0   10.0
# 4       M'Gladbach  ...     9.0      0.0       2       0       0   4.0    5.0
# 6     Union Berlin  ...     9.0      0.0       1       0       0  13.0   19.0
# ..             ...  ...     ...      ...     ...     ...     ...   ...    ...
# 22      Leverkusen  ...     5.0      0.0       1       0       0  11.0   18.0
# 23        Augsburg  ...    10.0      0.0       3       0       0   9.0    7.0
# 24        Dortmund  ...    15.0      0.0       1       0       0  11.0    7.0
# 25        Mainz 05  ...    16.0      0.0       1       0       0   9.0   10.0
# 26        Freiburg  ...     8.0      0.0       2       0       0   9.0   13.0
#
#    pkwon_y season           team
# 1      0.0   2023  Bayern Munich
# 2      0.0   2023  Bayern Munich
# 3      0.0   2023  Bayern Munich
# 4      0.0   2023  Bayern Munich
# 6      0.0   2023  Bayern Munich
# ..     ...    ...            ...
# 22     0.0   2023     Hoffenheim
# 23     0.0   2023     Hoffenheim
# 24     0.0   2023     Hoffenheim
# 25     0.0   2023     Hoffenheim
# 26     0.0   2023     Hoffenheim
#
# [432 rows x 47 columns]

# %%
import requests
standing_url = "https://fbref.com/en/comps/11/Serie-A-Stats"
data = requests.get(standing_url)
data.text
from bs4 import BeautifulSoup
soup = BeautifulSoup(data.text)
standing_table = soup.select("table.stats_table")[0]
standing_table
links  = standing_table.find_all("a")
links

links = [l.get("href") for l in links]
links
links = [l for l in links if '/squads/' in l]
links
team_urls = [f"https://fbref.com{l}" for l in links]
team_urls
team_url = team_urls[5]
data = requests.get(team_url)
data.text

import pandas as pd
matches = pd.read_html(data.text, match = "Scores & Fixtures")
matches

matches[0].head()
soup = BeautifulSoup(data.text)
links = soup.find_all("a")
links = [l.get("href") for l in links]
links = [l for l in links if l and "all_comps/keeper/" in l]
links
data = requests.get(f"https://fbref.com{links[0]}")
data.text

links2 = soup.find_all("a")
links2 = [l2.get("href") for l2 in links2]
links2 = [l2 for l2 in links2 if l2 and "all_comps/passing_types/" in l2]
data2 = requests.get(f"https://fbref.com{links2[0]}")
data2.text

links3 = soup.find_all("a")
links3 = [l3.get("href") for l3 in links3]
links3 = [l3 for l3 in links3 if l3 and "all_comps/misc/" in l3]
data3 = requests.get(f"https://fbref.com{links3[0]}")
data3.text

teamGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[0]
oppGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[1]
teamGoalKicks.head()
oppGoalKicks.head()

teampassing = pd.read_html(data2.text, match = "Pass Types")[0]
opppassing = pd.read_html(data2.text, match = "Pass Types")[1]
teampassing.head()
opppassing.head()

teammisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[0]
oppmisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[1]
teammisc.head()
oppmisc.head()

oppGoalKicks.columns = oppGoalKicks.columns.droplevel()
oppGoalKicks.head()
teamGoalKicks.columns = teamGoalKicks.columns.droplevel()
teamGoalKicks.head()


opppassing.columns = opppassing.columns.droplevel()
opppassing.head()
teampassing.columns = teampassing.columns.droplevel()
teampassing.head()

oppmisc.columns = oppmisc.columns.droplevel()
oppmisc.head()
teammisc.columns = teammisc.columns.droplevel()
teammisc.head()

team_data = matches[0].merge(teamGoalKicks[["Date", "Att"]], on = "Date").merge(oppGoalKicks[["Date", "Att"]], on = "Date").merge(teampassing[["Date", "Crs", "TI", "CK", "Off"]], on = "Date").merge(opppassing[["Date","Crs", "TI", "CK", "Off"]], on = "Date").merge(teammisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date").merge(oppmisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date")
team_data.head()

years = list(range(2023,2022,-1))
years


all_matches = []
standing_url = "https://fbref.com/en/comps/11/Serie-A-Stats" 

for year in years:
    data = requests.get(standing_url)
    soup = BeautifulSoup(data.text)
    standing_table = soup.select("table.stats_table")[0]
    
    links = standing_table.find_all("a")
    links = [l.get("href") for l in links]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
team_urls

team_urls[5].split("/")[-1].replace("-Stats", "")
team_urls[5].split("/")[-1].replace("-Stats", "").replace("-"," ")

import time
for year in years:
    data = requests.get(standing_url)
    soup = BeautifulSoup(data.text)
    standing_table = soup.select("table.stats_table")[0]
    
    links = standing_table.find_all("a")
    links = [l.get("href") for l in links]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-"," ")
        
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match= "Scores & Fixtures")[0]
        
        soup = BeautifulSoup(data.text)
        links = soup.find_all("a")
        links = [l.get("href") for l in links]
        links = [l for l in links if l and 'all_comps/keeper' in l]
        
        
        links2 = soup.find_all("a")
        links2 = [l2.get("href") for l2 in links2]
        links2 = [l2 for l2 in links2 if l2 and 'all_comps/passing_types' in l2]
        
        links3 = soup.find_all("a")
        links3 = [l3.get("href") for l3 in links3]
        links3 = [l3 for l3 in links3 if l3 and 'all_comps/misc' in l3]
        
        data = requests.get(f"https://fbref.com{links[0]}")
        teamGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[0]
        teamGoalKicks.columns = teamGoalKicks.columns.droplevel()
        oppGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[1]
        oppGoalKicks.columns = oppGoalKicks.columns.droplevel()
              
        data2 = requests.get(f"https://fbref.com{links2[0]}")
        teampassing = pd.read_html(data2.text, match = "Pass Types")[0]
        teampassing.columns = teampassing.columns.droplevel()
        opppassing = pd.read_html(data2.text, match = "Pass Types")[1]
        opppassing.columns = opppassing.columns.droplevel()
                       
        data3 = requests.get(f"https://fbref.com{links3[0]}")
        teammisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[0]
        teammisc.columns = teammisc.columns.droplevel()
        oppmisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[1]
        oppmisc.columns = oppmisc.columns.droplevel()
                         
        try:
            team_data = matches.merge(teampassing[["Date", "Crs", "TI", "CK", "Off"]], on = "Date").merge(opppassing[["Date", "Crs", "TI", "CK", "Off"]], on = "Date").merge(teamGoalKicks[["Date", "Att"]], on = "Date").merge(oppGoalKicks[["Date", "Att"]], on = "Date").merge(teammisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date").merge(oppmisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date")
       
        except ValueError:
            continue
            
        team_data = team_data[team_data["Comp"] == "Serie A"]
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(10)
        
match_df = pd.concat(all_matches)

match_df.columns = [c.lower() for c in match_df.columns]

match_df.to_csv("Ita1.csv")
match_df
# Out:
#           date   time     comp         round  day venue result gf ga  \
# 0   2022-08-15  18:30  Serie A   Matchweek 1  Mon  Away      W  5  2
# 1   2022-08-21  18:30  Serie A   Matchweek 2  Sun  Home      W  4  0
# 2   2022-08-28  20:45  Serie A   Matchweek 3  Sun  Away      D  0  0
# 3   2022-08-31  20:45  Serie A   Matchweek 4  Wed  Home      D  1  1
# 4   2022-09-03  20:45  Serie A   Matchweek 5  Sat  Away      W  2  1
# ..         ...    ...      ...           ...  ...   ...    ... .. ..
# 24  2023-02-13  20:45  Serie A  Matchweek 22  Mon  Home      D  0  0
# 25  2023-02-18  15:00  Serie A  Matchweek 23  Sat  Home      L  1  2
# 26  2023-02-27  20:45  Serie A  Matchweek 24  Mon  Away      L  0  1
# 27  2023-03-05  15:00  Serie A  Matchweek 25  Sun  Home      D  0  0
# 28  2023-03-12  20:45  Serie A  Matchweek 26  Sun  Away      L  2  4
#
#          opponent  ...  tklw_x  pkwon_x  crdy_y  crdr_y 2crdy_y int_y tklw_y  \
# 0   Hellas Verona  ...     7.0      0.0       2       0       0   9.0   10.0
# 1           Monza  ...     7.0      0.0       1       0       0   8.0   12.0
# 2      Fiorentina  ...    10.0      0.0       2       0       0   7.0   14.0
# 3           Lecce  ...    11.0      0.0       4       0       0  18.0   14.0
# 4           Lazio  ...     9.0      0.0       4       0       0  10.0   12.0
# ..            ...  ...     ...      ...     ...     ...     ...   ...    ...
# 24          Inter  ...     3.0      0.0       1       0       0  12.0    7.0
# 25        Bologna  ...    11.0      1.0       1       0       0   5.0   11.0
# 26          Lazio  ...    14.0      0.0       2       0       0   9.0    9.0
# 27    Salernitana  ...     7.0      0.0       4       0       0  12.0   10.0
# 28       Juventus  ...    11.0      0.0       1       0       0   4.0    5.0
#
#    pkwon_y season       team
# 0      0.0   2023     Napoli
# 1      0.0   2023     Napoli
# 2      0.0   2023     Napoli
# 3      1.0   2023     Napoli
# 4      0.0   2023     Napoli
# ..     ...    ...        ...
# 24     0.0   2023  Sampdoria
# 25     0.0   2023  Sampdoria
# 26     0.0   2023  Sampdoria
# 27     0.0   2023  Sampdoria
# 28     1.0   2023  Sampdoria
#
# [520 rows x 47 columns]

# %%
import requests
standing_url = "https://fbref.com/en/comps/12/La-Liga-Stats"
data = requests.get(standing_url)
data.text
from bs4 import BeautifulSoup
soup = BeautifulSoup(data.text)
standing_table = soup.select("table.stats_table")[0]
standing_table
links  = standing_table.find_all("a")
links

links = [l.get("href") for l in links]
links
links = [l for l in links if '/squads/' in l]
links
team_urls = [f"https://fbref.com{l}" for l in links]
team_urls
team_url = team_urls[5]
data = requests.get(team_url)
data.text

import pandas as pd
matches = pd.read_html(data.text, match = "Scores & Fixtures")
matches

matches[0].head()
soup = BeautifulSoup(data.text)
links = soup.find_all("a")
links = [l.get("href") for l in links]
links = [l for l in links if l and "all_comps/keeper/" in l]
links
data = requests.get(f"https://fbref.com{links[0]}")
data.text

links2 = soup.find_all("a")
links2 = [l2.get("href") for l2 in links2]
links2 = [l2 for l2 in links2 if l2 and "all_comps/passing_types/" in l2]
data2 = requests.get(f"https://fbref.com{links2[0]}")
data2.text

links3 = soup.find_all("a")
links3 = [l3.get("href") for l3 in links3]
links3 = [l3 for l3 in links3 if l3 and "all_comps/misc/" in l3]
data3 = requests.get(f"https://fbref.com{links3[0]}")
data3.text

teamGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[0]
oppGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[1]
teamGoalKicks.head()
oppGoalKicks.head()

teampassing = pd.read_html(data2.text, match = "Pass Types")[0]
opppassing = pd.read_html(data2.text, match = "Pass Types")[1]
teampassing.head()
opppassing.head()

teammisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[0]
oppmisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[1]
teammisc.head()
oppmisc.head()

oppGoalKicks.columns = oppGoalKicks.columns.droplevel()
oppGoalKicks.head()
teamGoalKicks.columns = teamGoalKicks.columns.droplevel()
teamGoalKicks.head()


opppassing.columns = opppassing.columns.droplevel()
opppassing.head()
teampassing.columns = teampassing.columns.droplevel()
teampassing.head()

oppmisc.columns = oppmisc.columns.droplevel()
oppmisc.head()
teammisc.columns = teammisc.columns.droplevel()
teammisc.head()

team_data = matches[0].merge(teamGoalKicks[["Date", "Att"]], on = "Date").merge(oppGoalKicks[["Date", "Att"]], on = "Date").merge(teampassing[["Date", "Crs", "TI", "CK", "Off"]], on = "Date").merge(opppassing[["Date","Crs", "TI", "CK", "Off"]], on = "Date").merge(teammisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date").merge(oppmisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date")
team_data.head()

years = list(range(2023,2022,-1))
years


all_matches = []
standing_url = "https://fbref.com/en/comps/12/La-Liga-Stats" 

for year in years:
    data = requests.get(standing_url)
    soup = BeautifulSoup(data.text)
    standing_table = soup.select("table.stats_table")[0]
    
    links = standing_table.find_all("a")
    links = [l.get("href") for l in links]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
team_urls

team_urls[5].split("/")[-1].replace("-Stats", "")
team_urls[5].split("/")[-1].replace("-Stats", "").replace("-"," ")

import time
for year in years:
    data = requests.get(standing_url)
    soup = BeautifulSoup(data.text)
    standing_table = soup.select("table.stats_table")[0]
    
    links = standing_table.find_all("a")
    links = [l.get("href") for l in links]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-"," ")
        
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match= "Scores & Fixtures")[0]
        
        soup = BeautifulSoup(data.text)
        links = soup.find_all("a")
        links = [l.get("href") for l in links]
        links = [l for l in links if l and 'all_comps/keeper' in l]
        
        
        links2 = soup.find_all("a")
        links2 = [l2.get("href") for l2 in links2]
        links2 = [l2 for l2 in links2 if l2 and 'all_comps/passing_types' in l2]
        
        links3 = soup.find_all("a")
        links3 = [l3.get("href") for l3 in links3]
        links3 = [l3 for l3 in links3 if l3 and 'all_comps/misc' in l3]
        
        data = requests.get(f"https://fbref.com{links[0]}")
        teamGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[0]
        teamGoalKicks.columns = teamGoalKicks.columns.droplevel()
        oppGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[1]
        oppGoalKicks.columns = oppGoalKicks.columns.droplevel()
              
        data2 = requests.get(f"https://fbref.com{links2[0]}")
        teampassing = pd.read_html(data2.text, match = "Pass Types")[0]
        teampassing.columns = teampassing.columns.droplevel()
        opppassing = pd.read_html(data2.text, match = "Pass Types")[1]
        opppassing.columns = opppassing.columns.droplevel()
                       
        data3 = requests.get(f"https://fbref.com{links3[0]}")
        teammisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[0]
        teammisc.columns = teammisc.columns.droplevel()
        oppmisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[1]
        oppmisc.columns = oppmisc.columns.droplevel()
                         
        try:
            team_data = matches.merge(teampassing[["Date", "Crs", "TI", "CK", "Off"]], on = "Date").merge(opppassing[["Date", "Crs", "TI", "CK", "Off"]], on = "Date").merge(teamGoalKicks[["Date", "Att"]], on = "Date").merge(oppGoalKicks[["Date", "Att"]], on = "Date").merge(teammisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date").merge(oppmisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date")
       
        except ValueError:
            continue
            
        team_data = team_data[team_data["Comp"] == "La Liga"]
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(10)
        
match_df = pd.concat(all_matches)

match_df.columns = [c.lower() for c in match_df.columns]

match_df.to_csv("Spa1.csv")
match_df
# Out:
#           date   time     comp         round  day venue result   gf   ga  \
# 0   2022-08-13  21:00  La Liga   Matchweek 1  Sat  Home      D    0    0
# 1   2022-08-21  22:00  La Liga   Matchweek 2  Sun  Away      W    4    1
# 2   2022-08-28  19:30  La Liga   Matchweek 3  Sun  Home      W    4    0
# 3   2022-09-03  21:00  La Liga   Matchweek 4  Sat  Away      W    3    0
# 5   2022-09-10  18:30  La Liga   Matchweek 5  Sat  Away      W    4    0
# ..         ...    ...      ...           ...  ...   ...    ...  ...  ...
# 23  2023-02-15  21:00  La Liga  Matchweek 21  Wed  Away      L  0.0  4.0
# 24  2023-02-19  14:00  La Liga  Matchweek 22  Sun  Home      L  0.0  1.0
# 25  2023-02-24  21:00  La Liga  Matchweek 23  Fri  Home      L  2.0  3.0
# 26  2023-03-04  18:30  La Liga  Matchweek 24  Sat  Away      W  1.0  0.0
# 27  2023-03-11  16:15  La Liga  Matchweek 25  Sat  Home      D  1.0  1.0
#
#           opponent  ...  tklw_x  pkwon_x  crdy_y  crdr_y 2crdy_y int_y tklw_y  \
# 0   Rayo Vallecano  ...    10.0      0.0       6       0       0  10.0   15.0
# 1    Real Sociedad  ...    11.0      0.0       2       0       0   5.0   13.0
# 2       Valladolid  ...    10.0      0.0       3       0       0   9.0   11.0
# 3          Sevilla  ...     8.0      0.0       2       0       0  17.0   15.0
# 5            Cádiz  ...     3.0      0.0       1       0       0  12.0   12.0
# ..             ...  ...     ...      ...     ...     ...     ...   ...    ...
# 23     Real Madrid  ...     9.0      0.0       1       0       0   3.0    9.0
# 24        Espanyol  ...    14.0      0.0       3       0       0   3.0    7.0
# 25           Betis  ...    10.0      1.0       1       0       0  10.0   13.0
# 26        Mallorca  ...     6.0      0.0       3       0       0  14.0    7.0
# 27      Valladolid  ...     7.0      0.0       6       2       2   7.0   18.0
#
#    pkwon_y season       team
# 0      0.0   2023  Barcelona
# 1      0.0   2023  Barcelona
# 2      0.0   2023  Barcelona
# 3      0.0   2023  Barcelona
# 5      0.0   2023  Barcelona
# ..     ...    ...        ...
# 23     1.0   2023      Elche
# 24     0.0   2023      Elche
# 25     1.0   2023      Elche
# 26     0.0   2023      Elche
# 27     0.0   2023      Elche
#
# [500 rows x 47 columns]

# %%
import requests
standing_url = "https://fbref.com/en/comps/23/Eredivisie-Stats"
data = requests.get(standing_url)
data.text
from bs4 import BeautifulSoup
soup = BeautifulSoup(data.text)
standing_table = soup.select("table.stats_table")[0]
standing_table
links  = standing_table.find_all("a")
links

links = [l.get("href") for l in links]
links
links = [l for l in links if '/squads/' in l]
links
team_urls = [f"https://fbref.com{l}" for l in links]
team_urls
team_url = team_urls[5]
data = requests.get(team_url)
data.text

import pandas as pd
matches = pd.read_html(data.text, match = "Scores & Fixtures")
matches

matches[0].head()
soup = BeautifulSoup(data.text)
links = soup.find_all("a")
links = [l.get("href") for l in links]
links = [l for l in links if l and "all_comps/keeper/" in l]
links
data = requests.get(f"https://fbref.com{links[0]}")
data.text

links2 = soup.find_all("a")
links2 = [l2.get("href") for l2 in links2]
links2 = [l2 for l2 in links2 if l2 and "all_comps/passing_types/" in l2]
data2 = requests.get(f"https://fbref.com{links2[0]}")
data2.text

links3 = soup.find_all("a")
links3 = [l3.get("href") for l3 in links3]
links3 = [l3 for l3 in links3 if l3 and "all_comps/misc/" in l3]
data3 = requests.get(f"https://fbref.com{links3[0]}")
data3.text

teamGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[0]
oppGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[1]
teamGoalKicks.head()
oppGoalKicks.head()

teampassing = pd.read_html(data2.text, match = "Pass Types")[0]
opppassing = pd.read_html(data2.text, match = "Pass Types")[1]
teampassing.head()
opppassing.head()

teammisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[0]
oppmisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[1]
teammisc.head()
oppmisc.head()

oppGoalKicks.columns = oppGoalKicks.columns.droplevel()
oppGoalKicks.head()
teamGoalKicks.columns = teamGoalKicks.columns.droplevel()
teamGoalKicks.head()


opppassing.columns = opppassing.columns.droplevel()
opppassing.head()
teampassing.columns = teampassing.columns.droplevel()
teampassing.head()

oppmisc.columns = oppmisc.columns.droplevel()
oppmisc.head()
teammisc.columns = teammisc.columns.droplevel()
teammisc.head()

team_data = matches[0].merge(teamGoalKicks[["Date", "Att"]], on = "Date").merge(oppGoalKicks[["Date", "Att"]], on = "Date").merge(teampassing[["Date", "Crs", "TI", "CK", "Off"]], on = "Date").merge(opppassing[["Date","Crs", "TI", "CK", "Off"]], on = "Date").merge(teammisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date").merge(oppmisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date")
team_data.head()

years = list(range(2023,2022,-1))
years


all_matches = []
standing_url = "https://fbref.com/en/comps/23/Eredivisie-Stats" 

for year in years:
    data = requests.get(standing_url)
    soup = BeautifulSoup(data.text)
    standing_table = soup.select("table.stats_table")[0]
    
    links = standing_table.find_all("a")
    links = [l.get("href") for l in links]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
team_urls

team_urls[5].split("/")[-1].replace("-Stats", "")
team_urls[5].split("/")[-1].replace("-Stats", "").replace("-"," ")

import time
for year in years:
    data = requests.get(standing_url)
    soup = BeautifulSoup(data.text)
    standing_table = soup.select("table.stats_table")[0]
    
    links = standing_table.find_all("a")
    links = [l.get("href") for l in links]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-"," ")
        
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match= "Scores & Fixtures")[0]
        
        soup = BeautifulSoup(data.text)
        links = soup.find_all("a")
        links = [l.get("href") for l in links]
        links = [l for l in links if l and 'all_comps/keeper' in l]
        
        
        links2 = soup.find_all("a")
        links2 = [l2.get("href") for l2 in links2]
        links2 = [l2 for l2 in links2 if l2 and 'all_comps/passing_types' in l2]
        
        links3 = soup.find_all("a")
        links3 = [l3.get("href") for l3 in links3]
        links3 = [l3 for l3 in links3 if l3 and 'all_comps/misc' in l3]
        
        data = requests.get(f"https://fbref.com{links[0]}")
        teamGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[0]
        teamGoalKicks.columns = teamGoalKicks.columns.droplevel()
        oppGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[1]
        oppGoalKicks.columns = oppGoalKicks.columns.droplevel()
              
        data2 = requests.get(f"https://fbref.com{links2[0]}")
        teampassing = pd.read_html(data2.text, match = "Pass Types")[0]
        teampassing.columns = teampassing.columns.droplevel()
        opppassing = pd.read_html(data2.text, match = "Pass Types")[1]
        opppassing.columns = opppassing.columns.droplevel()
                       
        data3 = requests.get(f"https://fbref.com{links3[0]}")
        teammisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[0]
        teammisc.columns = teammisc.columns.droplevel()
        oppmisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[1]
        oppmisc.columns = oppmisc.columns.droplevel()
                         
        try:
            team_data = matches.merge(teampassing[["Date", "Crs", "TI", "CK", "Off"]], on = "Date").merge(opppassing[["Date", "Crs", "TI", "CK", "Off"]], on = "Date").merge(teamGoalKicks[["Date", "Att"]], on = "Date").merge(oppGoalKicks[["Date", "Att"]], on = "Date").merge(teammisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date").merge(oppmisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date")
       
        except ValueError:
            continue
            
        team_data = team_data[team_data["Comp"] == "Eredivisie"]
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(10)
        
match_df = pd.concat(all_matches)

match_df.columns = [c.lower() for c in match_df.columns]

match_df.to_csv("Ned1.csv")
match_df
# Out:
#           date   time        comp         round  day venue result   gf   ga  \
# 0   2022-08-07  14:30  Eredivisie   Matchweek 1  Sun  Away      W  5.0  2.0
# 1   2022-08-13  21:00  Eredivisie   Matchweek 2  Sat  Home      D  0.0  0.0
# 2   2022-08-21  16:45  Eredivisie   Matchweek 3  Sun  Away      W  1.0  0.0
# 3   2022-08-27  20:00  Eredivisie   Matchweek 4  Sat  Home      W  4.0  0.0
# 4   2022-09-03  21:00  Eredivisie   Matchweek 5  Sat  Away      W  4.0  3.0
# ..         ...    ...         ...           ...  ...   ...    ...  ...  ...
# 20  2023-02-11  18:45  Eredivisie  Matchweek 21  Sat  Away      D  0.0  0.0
# 21  2023-02-19  12:15  Eredivisie  Matchweek 22  Sun  Home      L  1.0  2.0
# 22  2023-02-25  20:00  Eredivisie  Matchweek 23  Sat  Away      L  1.0  2.0
# 23  2023-03-05  20:00  Eredivisie  Matchweek 24  Sun  Home      W  4.0  1.0
# 24  2023-03-12  16:45  Eredivisie  Matchweek 25  Sun  Away      L  2.0  5.0
#
#          opponent  ...  tklw_x  pkwon_x  crdy_y  crdr_y 2crdy_y int_y tklw_y  \
# 0         Vitesse  ...    14.0      0.0       2       0       0   6.0   15.0
# 1      Heerenveen  ...     5.0      0.0       2       0       0  14.0    9.0
# 2    RKC Waalwijk  ...    12.0      1.0       2       0       0  11.0   13.0
# 3           Emmen  ...     9.0      0.0       0       0       0  14.0   15.0
# 4    Go Ahead Eag  ...    11.0      0.0       0       0       0  13.0    7.0
# ..            ...  ...     ...      ...     ...     ...     ...   ...    ...
# 20   NEC Nijmegen  ...     8.0      0.0       2       0       0   5.0    5.0
# 21     Heerenveen  ...    16.0      0.0       0       0       0   7.0    7.0
# 22     AZ Alkmaar  ...     8.0      1.0       3       0       0   9.0   11.0
# 23   Go Ahead Eag  ...     7.0      0.0       1       0       0   4.0    6.0
# 24  PSV Eindhoven  ...    11.0      0.0       1       0       0   6.0    6.0
#
#    pkwon_y season       team
# 0      0.0   2023  Feyenoord
# 1      0.0   2023  Feyenoord
# 2      0.0   2023  Feyenoord
# 3      0.0   2023  Feyenoord
# 4      0.0   2023  Feyenoord
# ..     ...    ...        ...
# 20     0.0   2023    Cambuur
# 21     0.0   2023    Cambuur
# 22     0.0   2023    Cambuur
# 23     0.0   2023    Cambuur
# 24     0.0   2023    Cambuur
#
# [448 rows x 47 columns]

# %%
import requests
standing_url = "https://fbref.com/en/comps/32/Primeira-Liga-Stats"
data = requests.get(standing_url)
data.text
from bs4 import BeautifulSoup
soup = BeautifulSoup(data.text)
standing_table = soup.select("table.stats_table")[0]
standing_table
links  = standing_table.find_all("a")
links

links = [l.get("href") for l in links]
links
links = [l for l in links if '/squads/' in l]
links
team_urls = [f"https://fbref.com{l}" for l in links]
team_urls
team_url = team_urls[5]
data = requests.get(team_url)
data.text

import pandas as pd
matches = pd.read_html(data.text, match = "Scores & Fixtures")
matches

matches[0].head()
soup = BeautifulSoup(data.text)
links = soup.find_all("a")
links = [l.get("href") for l in links]
links = [l for l in links if l and "all_comps/keeper/" in l]
links
data = requests.get(f"https://fbref.com{links[0]}")
data.text

links2 = soup.find_all("a")
links2 = [l2.get("href") for l2 in links2]
links2 = [l2 for l2 in links2 if l2 and "all_comps/passing_types/" in l2]
data2 = requests.get(f"https://fbref.com{links2[0]}")
data2.text

links3 = soup.find_all("a")
links3 = [l3.get("href") for l3 in links3]
links3 = [l3 for l3 in links3 if l3 and "all_comps/misc/" in l3]
data3 = requests.get(f"https://fbref.com{links3[0]}")
data3.text

teamGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[0]
oppGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[1]
teamGoalKicks.head()
oppGoalKicks.head()

teampassing = pd.read_html(data2.text, match = "Pass Types")[0]
opppassing = pd.read_html(data2.text, match = "Pass Types")[1]
teampassing.head()
opppassing.head()

teammisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[0]
oppmisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[1]
teammisc.head()
oppmisc.head()

oppGoalKicks.columns = oppGoalKicks.columns.droplevel()
oppGoalKicks.head()
teamGoalKicks.columns = teamGoalKicks.columns.droplevel()
teamGoalKicks.head()


opppassing.columns = opppassing.columns.droplevel()
opppassing.head()
teampassing.columns = teampassing.columns.droplevel()
teampassing.head()

oppmisc.columns = oppmisc.columns.droplevel()
oppmisc.head()
teammisc.columns = teammisc.columns.droplevel()
teammisc.head()

team_data = matches[0].merge(teamGoalKicks[["Date", "Att"]], on = "Date").merge(oppGoalKicks[["Date", "Att"]], on = "Date").merge(teampassing[["Date", "Crs", "TI", "CK", "Off"]], on = "Date").merge(opppassing[["Date","Crs", "TI", "CK", "Off"]], on = "Date").merge(teammisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date").merge(oppmisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date")
team_data.head()

years = list(range(2023,2022,-1))
years


all_matches = []
standing_url = "https://fbref.com/en/comps/32/Primeira-Liga-Stats" 

for year in years:
    data = requests.get(standing_url)
    soup = BeautifulSoup(data.text)
    standing_table = soup.select("table.stats_table")[0]
    
    links = standing_table.find_all("a")
    links = [l.get("href") for l in links]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
team_urls

team_urls[5].split("/")[-1].replace("-Stats", "")
team_urls[5].split("/")[-1].replace("-Stats", "").replace("-"," ")

import time
for year in years:
    data = requests.get(standing_url)
    soup = BeautifulSoup(data.text)
    standing_table = soup.select("table.stats_table")[0]
    
    links = standing_table.find_all("a")
    links = [l.get("href") for l in links]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-"," ")
        
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match= "Scores & Fixtures")[0]
        
        soup = BeautifulSoup(data.text)
        links = soup.find_all("a")
        links = [l.get("href") for l in links]
        links = [l for l in links if l and 'all_comps/keeper' in l]
        
        
        links2 = soup.find_all("a")
        links2 = [l2.get("href") for l2 in links2]
        links2 = [l2 for l2 in links2 if l2 and 'all_comps/passing_types' in l2]
        
        links3 = soup.find_all("a")
        links3 = [l3.get("href") for l3 in links3]
        links3 = [l3 for l3 in links3 if l3 and 'all_comps/misc' in l3]
        
        data = requests.get(f"https://fbref.com{links[0]}")
        teamGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[0]
        teamGoalKicks.columns = teamGoalKicks.columns.droplevel()
        oppGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[1]
        oppGoalKicks.columns = oppGoalKicks.columns.droplevel()
              
        data2 = requests.get(f"https://fbref.com{links2[0]}")
        teampassing = pd.read_html(data2.text, match = "Pass Types")[0]
        teampassing.columns = teampassing.columns.droplevel()
        opppassing = pd.read_html(data2.text, match = "Pass Types")[1]
        opppassing.columns = opppassing.columns.droplevel()
                       
        data3 = requests.get(f"https://fbref.com{links3[0]}")
        teammisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[0]
        teammisc.columns = teammisc.columns.droplevel()
        oppmisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[1]
        oppmisc.columns = oppmisc.columns.droplevel()
                         
        try:
            team_data = matches.merge(teampassing[["Date", "Crs", "TI", "CK", "Off"]], on = "Date").merge(opppassing[["Date", "Crs", "TI", "CK", "Off"]], on = "Date").merge(teamGoalKicks[["Date", "Att"]], on = "Date").merge(oppGoalKicks[["Date", "Att"]], on = "Date").merge(teammisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date").merge(oppmisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date")
       
        except ValueError:
            continue
            
        team_data = team_data[team_data["Comp"] == "Primeira Liga"]
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(10)
        
match_df = pd.concat(all_matches)

match_df.columns = [c.lower() for c in match_df.columns]

match_df.to_csv("Por1.csv")
match_df
# Out:
#           date   time           comp         round  day venue result   gf  \
# 1   2022-08-05  20:15  Primeira Liga   Matchweek 1  Fri  Home      W  4.0
# 3   2022-08-13  18:00  Primeira Liga   Matchweek 2  Sat  Away      W  1.0
# 6   2022-08-27  18:00  Primeira Liga   Matchweek 4  Sat  Away      W  3.0
# 7   2022-08-30  20:15  Primeira Liga   Matchweek 3  Tue  Home      W  3.0
# 8   2022-09-02  19:00  Primeira Liga   Matchweek 5  Fri  Home      W  2.0
# ..         ...    ...            ...           ...  ...   ...    ...  ...
# 19  2023-02-11  18:00  Primeira Liga  Matchweek 20  Sat  Away      L  0.0
# 20  2023-02-19  14:30  Primeira Liga  Matchweek 21  Sun  Home      L  1.0
# 21  2023-02-25  18:00  Primeira Liga  Matchweek 22  Sat  Away      L  1.0
# 22  2023-03-05  17:00  Primeira Liga  Matchweek 23  Sun  Home      L  1.0
# 23  2023-03-11  15:30  Primeira Liga  Matchweek 24  Sat  Away      L  0.0
#
#      ga   opponent  ...  tklw_x  pkwon_x  crdy_y  crdr_y 2crdy_y int_y tklw_y  \
# 1   0.0     Arouca  ...     8.0      0.0       1       1       0  15.0   10.0
# 3   0.0   Casa Pia  ...    12.0      0.0       6       0       0  16.0   15.0
# 6   0.0   Boavista  ...    16.0      1.0       4       0       0  11.0   14.0
# 7   2.0      Paços  ...     8.0      1.0       4       0       0  14.0    3.0
# 8   1.0     Vizela  ...     9.0      0.0       4       0       0  16.0   12.0
# ..  ...        ...  ...     ...      ...     ...     ...     ...   ...    ...
# 19  1.0     Arouca  ...    17.0      0.0       2       0       0  12.0   11.0
# 20  3.0  Famalicão  ...    11.0      0.0       3       1       0   7.0   11.0
# 21  3.0   Marítimo  ...    11.0      0.0       3       0       0  10.0    7.0
# 22  3.0    Vitória  ...     9.0      0.0       1       0       0   7.0   12.0
# 23  1.0      Paços  ...    17.0      0.0       5       0       0   6.0    4.0
#
#    pkwon_y season         team
# 1      0.0   2023      Benfica
# 3      0.0   2023      Benfica
# 6      0.0   2023      Benfica
# 7      0.0   2023      Benfica
# 8      0.0   2023      Benfica
# ..     ...    ...          ...
# 19     0.0   2023  Santa Clara
# 20     0.0   2023  Santa Clara
# 21     0.0   2023  Santa Clara
# 22     0.0   2023  Santa Clara
# 23     1.0   2023  Santa Clara
#
# [432 rows x 47 columns]

# %%
import requests
standing_url = "https://fbref.com/en/comps/9/Premier-League-Stats"
data = requests.get(standing_url)
data.text
from bs4 import BeautifulSoup
soup = BeautifulSoup(data.text)
standing_table = soup.select("table.stats_table")[0]
standing_table
links  = standing_table.find_all("a")
links

links = [l.get("href") for l in links]
links
links = [l for l in links if '/squads/' in l]
links
team_urls = [f"https://fbref.com{l}" for l in links]
team_urls
team_url = team_urls[5]
data = requests.get(team_url)
data.text

import pandas as pd
matches = pd.read_html(data.text, match = "Scores & Fixtures")
matches

matches[0].head()
soup = BeautifulSoup(data.text)
links = soup.find_all("a")
links = [l.get("href") for l in links]
links = [l for l in links if l and "all_comps/keeper/" in l]
links
data = requests.get(f"https://fbref.com{links[0]}")
data.text

links2 = soup.find_all("a")
links2 = [l2.get("href") for l2 in links2]
links2 = [l2 for l2 in links2 if l2 and "all_comps/passing_types/" in l2]
data2 = requests.get(f"https://fbref.com{links2[0]}")
data2.text

links3 = soup.find_all("a")
links3 = [l3.get("href") for l3 in links3]
links3 = [l3 for l3 in links3 if l3 and "all_comps/misc/" in l3]
data3 = requests.get(f"https://fbref.com{links3[0]}")
data3.text

teamGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[0]
oppGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[1]
teamGoalKicks.head()
oppGoalKicks.head()

teampassing = pd.read_html(data2.text, match = "Pass Types")[0]
opppassing = pd.read_html(data2.text, match = "Pass Types")[1]
teampassing.head()
opppassing.head()

teammisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[0]
oppmisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[1]
teammisc.head()
oppmisc.head()

oppGoalKicks.columns = oppGoalKicks.columns.droplevel()
oppGoalKicks.head()
teamGoalKicks.columns = teamGoalKicks.columns.droplevel()
teamGoalKicks.head()


opppassing.columns = opppassing.columns.droplevel()
opppassing.head()
teampassing.columns = teampassing.columns.droplevel()
teampassing.head()

oppmisc.columns = oppmisc.columns.droplevel()
oppmisc.head()
teammisc.columns = teammisc.columns.droplevel()
teammisc.head()

team_data = matches[0].merge(teamGoalKicks[["Date", "Att"]], on = "Date").merge(oppGoalKicks[["Date", "Att"]], on = "Date").merge(teampassing[["Date", "Crs", "TI", "CK", "Off"]], on = "Date").merge(opppassing[["Date","Crs", "TI", "CK", "Off"]], on = "Date").merge(teammisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date").merge(oppmisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date")
team_data.head()

years = list(range(2023,2022,-1))
years


all_matches = []
standing_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

for year in years:
    data = requests.get(standing_url)
    soup = BeautifulSoup(data.text)
    standing_table = soup.select("table.stats_table")[0]
    
    links = standing_table.find_all("a")
    links = [l.get("href") for l in links]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
team_urls

team_urls[5].split("/")[-1].replace("-Stats", "")
team_urls[5].split("/")[-1].replace("-Stats", "").replace("-"," ")

import time
for year in years:
    data = requests.get(standing_url)
    soup = BeautifulSoup(data.text)
    standing_table = soup.select("table.stats_table")[0]
    
    links = standing_table.find_all("a")
    links = [l.get("href") for l in links]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-"," ")
        
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match= "Scores & Fixtures")[0]
        
        soup = BeautifulSoup(data.text)
        links = soup.find_all("a")
        links = [l.get("href") for l in links]
        links = [l for l in links if l and 'all_comps/keeper' in l]
        
        
        links2 = soup.find_all("a")
        links2 = [l2.get("href") for l2 in links2]
        links2 = [l2 for l2 in links2 if l2 and 'all_comps/passing_types' in l2]
        
        links3 = soup.find_all("a")
        links3 = [l3.get("href") for l3 in links3]
        links3 = [l3 for l3 in links3 if l3 and 'all_comps/misc' in l3]
        
        data = requests.get(f"https://fbref.com{links[0]}")
        teamGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[0]
        teamGoalKicks.columns = teamGoalKicks.columns.droplevel()
        oppGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[1]
        oppGoalKicks.columns = oppGoalKicks.columns.droplevel()
              
        data2 = requests.get(f"https://fbref.com{links2[0]}")
        teampassing = pd.read_html(data2.text, match = "Pass Types")[0]
        teampassing.columns = teampassing.columns.droplevel()
        opppassing = pd.read_html(data2.text, match = "Pass Types")[1]
        opppassing.columns = opppassing.columns.droplevel()
                       
        data3 = requests.get(f"https://fbref.com{links3[0]}")
        teammisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[0]
        teammisc.columns = teammisc.columns.droplevel()
        oppmisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[1]
        oppmisc.columns = oppmisc.columns.droplevel()
                         
        try:
            team_data = matches.merge(teampassing[["Date", "Crs", "TI", "CK", "Off"]], on = "Date").merge(opppassing[["Date", "Crs", "TI", "CK", "Off"]], on = "Date").merge(teamGoalKicks[["Date", "Att"]], on = "Date").merge(oppGoalKicks[["Date", "Att"]], on = "Date").merge(teammisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date").merge(oppmisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date")
       
        except ValueError:
            continue
            
        team_data = team_data[team_data["Comp"] == "Premier League"]
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(10)
        
match_df = pd.concat(all_matches)

match_df.columns = [c.lower() for c in match_df.columns]

match_df.to_csv("Eng1.csv")
match_df
# Out:
#           date   time            comp         round  day venue result   gf  \
# 0   2022-08-05  20:00  Premier League   Matchweek 1  Fri  Away      W  2.0
# 1   2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 2   2022-08-20  17:30  Premier League   Matchweek 3  Sat  Away      W  3.0
# 3   2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W  2.0
# 4   2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  2.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 30  2023-02-18  15:00  Premier League  Matchweek 24  Sat  Away      W    1
# 31  2023-02-25  15:00  Premier League  Matchweek 25  Sat  Away      L    0
# 33  2023-03-04  17:30  Premier League  Matchweek 26  Sat  Home      W    1
# 34  2023-03-12  14:00  Premier League  Matchweek 27  Sun  Away      D    0
# 35  2023-03-15  19:30  Premier League   Matchweek 7  Wed  Home      L    0
#
#      ga        opponent  ...  tklw_x  pkwon_x  crdy_y  crdr_y 2crdy_y int_y  \
# 0   0.0  Crystal Palace  ...    16.0      0.0       1       0       0   8.0
# 1   2.0  Leicester City  ...     6.0      0.0       1       0       0   8.0
# 2   0.0     Bournemouth  ...     8.0      0.0       2       0       0   7.0
# 3   1.0          Fulham  ...    11.0      0.0       3       0       0  14.0
# 4   1.0     Aston Villa  ...     7.0      0.0       3       0       0  11.0
# ..  ...             ...  ...     ...      ...     ...     ...     ...   ...
# 30    0         Chelsea  ...    22.0      0.0       3       0       0   8.0
# 31    1    Leeds United  ...    15.0      0.0       2       0       0   8.0
# 33    0  Leicester City  ...     9.0      0.0       2       0       0  10.0
# 34    0  Manchester Utd  ...    10.0      0.0       2       1       0   3.0
# 35    2       Brentford  ...     6.0      0.0       2       0       0  14.0
#
#    tklw_y pkwon_y season         team
# 0     9.0     0.0   2023      Arsenal
# 1     7.0     0.0   2023      Arsenal
# 2     8.0     0.0   2023      Arsenal
# 3    11.0     0.0   2023      Arsenal
# 4     6.0     0.0   2023      Arsenal
# ..    ...     ...    ...          ...
# 30   13.0     0.0   2023  Southampton
# 31   15.0     0.0   2023  Southampton
# 33   14.0     0.0   2023  Southampton
# 34    8.0     0.0   2023  Southampton
# 35   11.0     0.0   2023  Southampton
#
# [526 rows x 47 columns]

# %%
import requests
standing_url = "https://fbref.com/en/comps/13/Ligue-1-Stats"
data = requests.get(standing_url)
data.text
from bs4 import BeautifulSoup
soup = BeautifulSoup(data.text)
standing_table = soup.select("table.stats_table")[0]
standing_table
links  = standing_table.find_all("a")
links

links = [l.get("href") for l in links]
links
links = [l for l in links if '/squads/' in l]
links
team_urls = [f"https://fbref.com{l}" for l in links]
team_urls
team_url = team_urls[5]
data = requests.get(team_url)
data.text

import pandas as pd
matches = pd.read_html(data.text, match = "Scores & Fixtures")
matches

matches[0].head()
soup = BeautifulSoup(data.text)
links = soup.find_all("a")
links = [l.get("href") for l in links]
links = [l for l in links if l and "all_comps/keeper/" in l]
links
data = requests.get(f"https://fbref.com{links[0]}")
data.text

links2 = soup.find_all("a")
links2 = [l2.get("href") for l2 in links2]
links2 = [l2 for l2 in links2 if l2 and "all_comps/passing_types/" in l2]
data2 = requests.get(f"https://fbref.com{links2[0]}")
data2.text

links3 = soup.find_all("a")
links3 = [l3.get("href") for l3 in links3]
links3 = [l3 for l3 in links3 if l3 and "all_comps/misc/" in l3]
data3 = requests.get(f"https://fbref.com{links3[0]}")
data3.text

teamGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[0]
oppGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[1]
teamGoalKicks.head()
oppGoalKicks.head()

teampassing = pd.read_html(data2.text, match = "Pass Types")[0]
opppassing = pd.read_html(data2.text, match = "Pass Types")[1]
teampassing.head()
opppassing.head()

teammisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[0]
oppmisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[1]
teammisc.head()
oppmisc.head()

oppGoalKicks.columns = oppGoalKicks.columns.droplevel()
oppGoalKicks.head()
teamGoalKicks.columns = teamGoalKicks.columns.droplevel()
teamGoalKicks.head()


opppassing.columns = opppassing.columns.droplevel()
opppassing.head()
teampassing.columns = teampassing.columns.droplevel()
teampassing.head()

oppmisc.columns = oppmisc.columns.droplevel()
oppmisc.head()
teammisc.columns = teammisc.columns.droplevel()
teammisc.head()

team_data = matches[0].merge(teamGoalKicks[["Date", "Att"]], on = "Date").merge(oppGoalKicks[["Date", "Att"]], on = "Date").merge(teampassing[["Date", "Crs", "TI", "CK", "Off"]], on = "Date").merge(opppassing[["Date","Crs", "TI", "CK", "Off"]], on = "Date").merge(teammisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date").merge(oppmisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date")
team_data.head()

years = list(range(2023,2022,-1))
years


all_matches = []
standing_url = "https://fbref.com/en/comps/13/Ligue-1-Stats"

for year in years:
    data = requests.get(standing_url)
    soup = BeautifulSoup(data.text)
    standing_table = soup.select("table.stats_table")[0]
    
    links = standing_table.find_all("a")
    links = [l.get("href") for l in links]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
team_urls

team_urls[5].split("/")[-1].replace("-Stats", "")
team_urls[5].split("/")[-1].replace("-Stats", "").replace("-"," ")

import time
for year in years:
    data = requests.get(standing_url)
    soup = BeautifulSoup(data.text)
    standing_table = soup.select("table.stats_table")[0]
    
    links = standing_table.find_all("a")
    links = [l.get("href") for l in links]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-"," ")
        
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match= "Scores & Fixtures")[0]
        
        soup = BeautifulSoup(data.text)
        links = soup.find_all("a")
        links = [l.get("href") for l in links]
        links = [l for l in links if l and 'all_comps/keeper' in l]
        
        
        links2 = soup.find_all("a")
        links2 = [l2.get("href") for l2 in links2]
        links2 = [l2 for l2 in links2 if l2 and 'all_comps/passing_types' in l2]
        
        links3 = soup.find_all("a")
        links3 = [l3.get("href") for l3 in links3]
        links3 = [l3 for l3 in links3 if l3 and 'all_comps/misc' in l3]
        
        data = requests.get(f"https://fbref.com{links[0]}")
        teamGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[0]
        teamGoalKicks.columns = teamGoalKicks.columns.droplevel()
        oppGoalKicks = pd.read_html(data.text, match = "Goalkeeping")[1]
        oppGoalKicks.columns = oppGoalKicks.columns.droplevel()
              
        data2 = requests.get(f"https://fbref.com{links2[0]}")
        teampassing = pd.read_html(data2.text, match = "Pass Types")[0]
        teampassing.columns = teampassing.columns.droplevel()
        opppassing = pd.read_html(data2.text, match = "Pass Types")[1]
        opppassing.columns = opppassing.columns.droplevel()
                       
        data3 = requests.get(f"https://fbref.com{links3[0]}")
        teammisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[0]
        teammisc.columns = teammisc.columns.droplevel()
        oppmisc = pd.read_html(data3.text, match = "Miscellaneous Stats")[1]
        oppmisc.columns = oppmisc.columns.droplevel()
                         
        try:
            team_data = matches.merge(teampassing[["Date", "Crs", "TI", "CK", "Off"]], on = "Date").merge(opppassing[["Date", "Crs", "TI", "CK", "Off"]], on = "Date").merge(teamGoalKicks[["Date", "Att"]], on = "Date").merge(oppGoalKicks[["Date", "Att"]], on = "Date").merge(teammisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date").merge(oppmisc[["Date", "CrdY", "CrdR", "2CrdY", "Int", "TklW", "PKwon"]], on = "Date")
       
        except ValueError:
            continue
            
        team_data = team_data[team_data["Comp"] == "Ligue 1"]
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(10)
        
match_df = pd.concat(all_matches)

match_df.columns = [c.lower() for c in match_df.columns]

match_df.to_csv("Fra1.csv")
match_df
# Out:
#           date   time     comp         round  day venue result   gf   ga  \
# 1   2022-08-06  21:00  Ligue 1   Matchweek 1  Sat  Away      W  5.0  0.0
# 2   2022-08-13  21:00  Ligue 1   Matchweek 2  Sat  Home      W  5.0  2.0
# 3   2022-08-21  20:45  Ligue 1   Matchweek 3  Sun  Away      W  7.0  1.0
# 4   2022-08-28  20:45  Ligue 1   Matchweek 4  Sun  Home      D  1.0  1.0
# 5   2022-08-31  21:00  Ligue 1   Matchweek 5  Wed  Away      W  3.0  0.0
# ..         ...    ...      ...           ...  ...   ...    ...  ...  ...
# 25  2023-02-12  15:00  Ligue 1  Matchweek 23  Sun  Home      D    1    1
# 26  2023-02-18  21:00  Ligue 1  Matchweek 24  Sat  Away      L    1    2
# 27  2023-02-25  17:00  Ligue 1  Matchweek 25  Sat  Home      L    1    3
# 28  2023-03-05  15:00  Ligue 1  Matchweek 26  Sun  Away      L    0    5
# 29  2023-03-12  15:00  Ligue 1  Matchweek 27  Sun  Home      L    0    2
#
#          opponent  ...  tklw_x  pkwon_x  crdy_y  crdr_y 2crdy_y int_y tklw_y  \
# 1   Clermont Foot  ...     5.0      0.0       2       0       0  12.0   11.0
# 2     Montpellier  ...    12.0      0.0       1       0       0   9.0   13.0
# 3           Lille  ...     8.0      0.0       2       0       0  15.0    5.0
# 4          Monaco  ...    11.0      1.0       4       0       0  16.0   15.0
# 5        Toulouse  ...    12.0      0.0       1       0       0  12.0   21.0
# ..            ...  ...     ...      ...     ...     ...     ...   ...    ...
# 25        Auxerre  ...    11.0      0.0       0       0       0  10.0   10.0
# 26     Strasbourg  ...    11.0      1.0       3       0       0  12.0   15.0
# 27           Lyon  ...    14.0      0.0       0       0       0  11.0   14.0
# 28    Montpellier  ...     9.0      0.0       1       0       0  11.0   12.0
# 29       Toulouse  ...     7.0      0.0       1       0       0  13.0    9.0
#
#    pkwon_y season                 team
# 1      0.0   2023  Paris Saint Germain
# 2      0.0   2023  Paris Saint Germain
# 3      0.0   2023  Paris Saint Germain
# 4      0.0   2023  Paris Saint Germain
# 5      0.0   2023  Paris Saint Germain
# ..     ...    ...                  ...
# 25     1.0   2023               Angers
# 26     0.0   2023               Angers
# 27     0.0   2023               Angers
# 28     1.0   2023               Angers
# 29     0.0   2023               Angers
#
# [540 rows x 47 columns]
